# %%
import pandas as pd

# %%
df = pd.read_csv("../hp/Book1.csv")
print(df.to_string())
# Out:
#    Unnamed: 0.1  Unnamed: 0 Height Weight  Age Grip Strength Frailty
# 0             0           0  65.8    112   30            30       N
# 1             1           1  71.5    136   19            31       N
# 2             2           2  69.4    153   45            29       N
# 3             3           3  68.2    142   22            28       Y
# 4             4           4  67.8    144   29            24       Y
# 5             5           5  68.7    123   50            26       N
# 6             6           6  69.8    141   51            22       Y
# 7             7           7  70.1    136   23            20       Y
# 8             8           8  67.9    112   17            19       N
# 9             9           9  66.8    120   39            31       N

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0.1   10 non-null     int64
#  1   Unnamed: 0     10 non-null     int64
#  2   Height         10 non-null     object
#  3   Weight         10 non-null     object
#  4   Age            10 non-null     object
#  5   Grip Strength  10 non-null     object
#  6   Frailty        10 non-null     object
# dtypes: int64(2), object(5)
# memory usage: 692.0+ bytes

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
ax=sns.distplot(df['Age'], kde = False, color ='green', bins = 30)
fig=ax.get_figure()
fig.savefig("../hp/Age_Distibution.png")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7944\115336559.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(df['Age'], kde = False, color ='green', bins = 30)

# %%
ax=sns.distplot(df['Grip Strength'], kde = False, color ='red', bins = 30)
fig=ax.get_figure()
fig.savefig("../hp/Grip_Strength_Distibution.png")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7944\3706994932.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(df['Grip Strength'], kde = False, color ='red', bins = 30)

# %%
ax = df.plot.scatter(x='Age',y='Grip Strength')
fig=ax.get_figure()
fig.savefig("../hp/Grip_Strength_Age_Relation.png")

# %%
ax = df.plot.scatter(x='Weight',y='Grip Strength')
fig=ax.get_figure()
fig.savefig("../hp/GripStrength_Weight_Relation.png")
